# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("prac/Iris.csv")
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.iloc[-5:,:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#8
unq_label = df['Species'].unique()
unq_label
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#9
u = df['Species'].value_counts()
u
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.isnull().sum().reset_index(name="count")
# Out:
#            index  count
# 0             Id      0
# 1  SepalLengthCm      0
# 2   SepalWidthCm      0
# 3  PetalLengthCm      0
# 4   PetalWidthCm      0
# 5        Species      0

# %%
#10
d=df.drop(columns=['Id'])
d
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#11
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#12

plot_co = df.drop(columns=['Id','Species'])

fig,axes=plt.subplots(2,2,figsize=(25,15))
axes = axes.flatten()

i=0

for col in plot_co:
    axes[i].hist(df[col],bins=40,alpha=0.9,color="pink")
    axes[i].set_title(f"{col}")
    i+=1

# %%
plot_co.select_dtypes(include=['number']).columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
plt.scatter(x=df['SepalWidthCm'],y=df['SepalLengthCm'])
plt.grid()

# %%
import seaborn as sns
sns.scatterplot(x=df['SepalWidthCm'],y=df['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
sns.boxplot(data=df,x=df['PetalWidthCm'],y=df['Species'])
plt.xlabel("PetalWidthCm")
# Out:
# Text(0.5, 0, 'PetalWidthCm')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df,x=df['PetalLengthCm'],y=df['Species'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Species'>

# %%
df.boxplot(column="PetalLengthCm",by="Species")
# Out:
# <Axes: title={'center': 'PetalLengthCm'}, xlabel='Species'>

# %%
#14
g=sns.FacetGrid(df,hue="Species",height=5)
g.map(sns.scatterplot,"SepalLengthCm","SepalWidthCm")
g.add_legend()

# %%
plt.figure(figsize=(6,3))
sns.pairplot(df,hue="Species")

# %%
#18

print(f"corelaton between speal length and width :{df['SepalLengthCm'].corr(df['SepalWidthCm'])}")
# Out:
# corelaton between speal length and width :-0.10936924995064937

# %%
print(f"corelaton between petal length and width :{df['PetalLengthCm'].corr(df['PetalWidthCm'])}")
# Out:
# corelaton between petal length and width :0.9627570970509663

# %%
x=df.drop(columns=['Id','Species'])
y=df['Species']

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,train_size=0.7,random_state=1)

# %%
df.corr(numeric_only=True)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
from sklearn.svm import SVC
#s = SVC(kernal="linear")
help(SVC)
# Out:
# Help on class SVC in module sklearn.svm._classes:
#
# class SVC(sklearn.svm._base.BaseSVC)
#  |  SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
#  |
#  |  C-Support Vector Classification.
#  |
#  |  The implementation is based on libsvm. The fit time scales at least
#  |  quadratically with the number of samples and may be impractical
#  |  beyond tens of thousands of samples. For large datasets
#  |  consider using :class:`~sklearn.svm.LinearSVC` or
#  |  :class:`~sklearn.linear_model.SGDClassifier` instead, possibly after a
#  |  :class:`~sklearn.kernel_approximation.Nystroem` transformer or
#  |  other :ref:`kernel_approximation`.
#  |
#  |  The multiclass support is handled according to a one-vs-one scheme.
#  |
#  |  For details on the precise mathematical formulation of the provided
# ...

# %%
#22
model = SVC(kernel='linear')

# %%
#23
model = SVC(C=1)

# %%
model.fit(x_train,y_train)
# Out:
# SVC(C=1)

# %%
y_pred = model.predict(x_test).tolist()

# %%
y_pred
# Out:
# ['Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-setosa',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-virginica',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-virginica',
#  'Iris-virginica',
#  'Iris-setosa',
#  'Iris-virginica',
#  'Iris-virginica',
#  'Iris-versicolor']

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 14             5.8           4.0            1.2           0.2
# 98             5.1           2.5            3.0           1.1
# 75             6.6           3.0            4.4           1.4
# 16             5.4           3.9            1.3           0.4
# 131            7.9           3.8            6.4           2.0
# 56             6.3           3.3            4.7           1.6
# 141            6.9           3.1            5.1           2.3
# 44             5.1           3.8            1.9           0.4
# 29             4.7           3.2            1.6           0.2
# 120            6.9           3.2            5.7           2.3
# 94             5.6           2.7            4.2           1.3
# 5              5.4           3.9            1.7           0.4
# 102            7.1           3.0            5.9           2.1
# 51             6.4           3.2            4.5           1.5
# ...

# %%
df.head(14)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...
